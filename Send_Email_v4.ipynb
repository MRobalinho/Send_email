# %% [markdown]
# #  SEND email with attach file JPG, PDF and .ICS (Calendar event)
#
# https://stackoverflow.com/questions/10147455/how-to-send-an-email-with-gmail-as-provider-using-python/27515833#27515833
#
# ### Tested OK
#
# https://code.tutsplus.com/pt/tutorials/sending-emails-in-python-with-smtp--cms-29975
# https://realpython.com/python-send-email/
# https://www.programcreek.com/python/example/103416/email.mime.image.MIMEImage
#
#
# To create .ics eventos: https://ical.marudot.com/

# %%
# pip install mimelib

import smtplib
import os
import numpy as np
from time import gmtime, strftime 
from email.mime.multipart import MIMEMultipart
from email.mime.image import MIMEImage
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email.mime.application import MIMEApplication
from email import encoders

# %%
import pandas as pd

# File Exel
xls_file = 'data_to_send.xlsx'
print('-----  ENVIO DE EMAILS ------')
print('Lendo arquivo :', xls_file)

df = pd.read_excel(xls_file, sheet_name='Sheet1')

# print whole sheet data
df
# Out:
# -----  ENVIO DE EMAILS ------
# Lendo arquivo : data_to_send.xlsx
#     Cliente                            Nome 1  Unnamed: 2    Nº doc.  Itm  \
# 0      4112       ACO CEARENSE COMERCIAL LTDA         NaN   90549749    1
# 1    100003  IND COM DE FERROS BORTOLASO LTDA         NaN   90554973    1
# 2    100034             CHAPADAOFER IND E COM         NaN   90537461    2
# 3    100034             CHAPADAOFER IND E COM         NaN   90537461    3
# 4    100034             CHAPADAOFER IND E COM         NaN   90537462    1
# 5    100034             CHAPADAOFER IND E COM         NaN   90537462    2
# 6    100035                   M 3 CONSTR LTDA         NaN   90553111    1
# 7    100045              PRIMACO COM DE FERRO         NaN  100547310    1
# 8    100047                   VERDEACO COM DE         NaN   90510128    3
# 9    100047                   VERDEACO COM DE         NaN   90523815    2
# 10   100047                   VERDEACO COM DE         NaN   90523815    3
# 11   100047                   VERDEACO COM DE         NaN   90523816    2
# 12   100047                   VERDEACO COM DE         NaN   90523816    3
# 13   100048                 RONDOFERRO COM DE         NaN   90498413    3
# 14   100048                 RONDOFERRO COM DE         NaN   90524158    2
# 15   100048                 RONDOFERRO COM DE         NaN   90524158    3
# 16   100053               LEO CONSTR LTDA EPP         NaN   90476020    3
# 17   100053               LEO CONSTR LTDA EPP         NaN   90492243    3
# 18   100053               LEO CONSTR LTDA EPP         NaN   90492244    3
# 19   100053               LEO CONSTR LTDA EPP         NaN   90492245    3
#
#        Referência Dt.Vencimento       Montante  \
# 0   000190479-001    09.04.2016       37060.58
# 1   000192232-001    15.04.2018        1001.60
# 2   000185879-001    23.01.2016        3995.84
# 3   000185879-001    22.02.2016        3995.96
# 4   000185880-001    24.12.2015         924.86
# 5   000185880-001    23.01.2016         924.86
# 6   000078223-001    25.10.2016       60112.50
# 7   000177323-001    22.05.2018      439502.86
# 8   000177083-001    12.01.2016        2177.81
# 9   000181253-001    03.01.2016       13699.22
# 10  000181253-001    02.02.2016       13699.64
# 11  000181254-001    03.01.2016        2177.69
# 12  000181254-001    02.02.2016        2177.75
# 13  000173415-001    24.12.2015       19011.61
# 14  000181350-001    03.01.2016        8390.74
# 15  000181350-001    02.02.2016        8391.00
# 16  000164846-001    23.11.2015       20692.30
# 17  000171092-001    15.12.2015        2348.94
# 18  000171093-001    15.12.2015       16541.28
# 19  000171094-001    15.12.2015        4089.46
#
#                                   Email    file_pdf    file_jpg  \
# 0   manuel.robalinho@acocearense.com.br  teste1.pdf  teste1.jpg
# 1   manuel.robalinho@acocearense.com.br  teste2.pdf  teste2.jpg
# 2                mrobalinho@hotmail.com  teste2.pdf         NaN
# 3                mrobalinho@hotmail.com         NaN         NaN
# 4                                   NaN         NaN         NaN
# 5                                   NaN         NaN         NaN
# 6                                   NaN         NaN         NaN
# 7                                   NaN         NaN         NaN
# 8                                   NaN         NaN         NaN
# 9                                   NaN         NaN         NaN
# 10                                  NaN         NaN         NaN
# 11                                  NaN         NaN         NaN
# 12                                  NaN         NaN         NaN
# 13                                  NaN         NaN         NaN
# 14                                  NaN         NaN         NaN
# 15                                  NaN         NaN         NaN
# 16                                  NaN         NaN         NaN
# 17                                  NaN         NaN         NaN
# 18                                  NaN         NaN         NaN
# 19                                  NaN         NaN         NaN
#
#                  file_event
# 0   EVENTO_DO_ROBALINHO.ics
# 1   EVENTO_DO_ROBALINHO.ics
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN

# %%
df.dtypes
# Out:
# Cliente            int64
# Nome 1            object
# Unnamed: 2       float64
# Nº doc.            int64
# Itm                int64
# Referência        object
# Dt.Vencimento     object
#      Montante    float64
# Email             object
# file_pdf          object
# file_jpg          object
# file_event        object
# dtype: object

# %%
df.columns = ['cliente', 'nome', 'zz', 'doc', 'item', 'referencia', 'vencimento', 'montante', 'email','file_pdf','file_jpg','file_event']

# %%
# Only rows with email
df2 = df.dropna(subset=['email']).copy()

# %%
df2.head()
# Out:
#    cliente                              nome  zz       doc  item  \
# 0     4112       ACO CEARENSE COMERCIAL LTDA NaN  90549749     1
# 1   100003  IND COM DE FERROS BORTOLASO LTDA NaN  90554973     1
# 2   100034             CHAPADAOFER IND E COM NaN  90537461     2
# 3   100034             CHAPADAOFER IND E COM NaN  90537461     3
#
#       referencia  vencimento  montante                                email  \
# 0  000190479-001  09.04.2016  37060.58  manuel.robalinho@acocearense.com.br
# 1  000192232-001  15.04.2018   1001.60  manuel.robalinho@acocearense.com.br
# 2  000185879-001  23.01.2016   3995.84               mrobalinho@hotmail.com
# 3  000185879-001  22.02.2016   3995.96               mrobalinho@hotmail.com
#
#      file_pdf    file_jpg               file_event
# 0  teste1.pdf  teste1.jpg  EVENTO_DO_ROBALINHO.ics
# 1  teste2.pdf  teste2.jpg  EVENTO_DO_ROBALINHO.ics
# 2  teste2.pdf         NaN                      NaN
# 3         NaN         NaN                      NaN

# %%
# for column
df2['file_pdf'].replace(np.nan, '', inplace=True)
df2['file_jpg'].replace(np.nan, '', inplace=True)
df2['file_event'].replace(np.nan, '', inplace=True)

# %%
df2.head()
# Out:
#    cliente                              nome  zz       doc  item  \
# 0     4112       ACO CEARENSE COMERCIAL LTDA NaN  90549749     1
# 1   100003  IND COM DE FERROS BORTOLASO LTDA NaN  90554973     1
# 2   100034             CHAPADAOFER IND E COM NaN  90537461     2
# 3   100034             CHAPADAOFER IND E COM NaN  90537461     3
#
#       referencia  vencimento  montante                                email  \
# 0  000190479-001  09.04.2016  37060.58  manuel.robalinho@acocearense.com.br
# 1  000192232-001  15.04.2018   1001.60  manuel.robalinho@acocearense.com.br
# 2  000185879-001  23.01.2016   3995.84               mrobalinho@hotmail.com
# 3  000185879-001  22.02.2016   3995.96               mrobalinho@hotmail.com
#
#      file_pdf    file_jpg               file_event
# 0  teste1.pdf  teste1.jpg  EVENTO_DO_ROBALINHO.ics
# 1  teste2.pdf  teste2.jpg  EVENTO_DO_ROBALINHO.ics
# 2  teste2.pdf
# 3

# %%
df2.dtypes
# Out:
# cliente         int64
# nome           object
# zz            float64
# doc             int64
# item            int64
# referencia     object
# vencimento     object
# montante      float64
# email          object
# file_pdf       object
# file_jpg       object
# file_event     object
# dtype: object

# %%
# Send Email function
def send_email(fromaddr, toaddrs, msg):
    username = 'your@gmail.com'
    # a password é obtiga na configuração de segurança em 2 passos do google
    # ao definir password para acesso de APPs
    password = 'your'
    #....
    server = smtplib.SMTP_SSL("smtp.gmail.com",465)
    server.ehlo()
    server.login(username, password)
    server.sendmail(fromaddr, toaddrs, msg)
    server.close()
    print('4.Successfully sent the mail to :',toaddrs)

    return
#-------------------------------------------

# %%
# create message object instance
msg = MIMEMultipart()

def create_msg_email(nome, xdoc, xdata, xemail, xvalor, xfile_pdf, xfile_jpg, xfile_event):
    msg = MIMEMultipart()
    
    path = 'files_to_attach/'
    
    fromaddr = 'manuel.robalinho@gmail.com'
    toaddrs  = xemail
    print('2.Create msg :',nome, xdoc, xdata, xvalor)
    
    # Identificação do doc
    doc   = xdoc
    data  = xdata
    valor = xvalor
   
    # Image File
    if xfile_jpg is not '':
        image_file = path + xfile_jpg
        img_data = open(image_file, 'rb').read()
    
    # Pdf File
    file_pdf = ''
    if xfile_pdf is not '':
        file_pdf = path + xfile_pdf

    # Calendar Event file
    file_event = ''
    if xfile_event is not '':
        file_event = path + xfile_event
        
    #
    password = "your_password"
    msg['From'] = fromaddr
    msg['To']   = toaddrs
    msg['Subject'] = " Vencimento do documento:"+str(doc)+" em "+data+ "  Valor:"+str(valor)

    # Mensagem HTML
    message = "\r\n".join([
      "From: "+fromaddr+"<br>",
      "To: "+toaddrs+"<br>",
      "<br>",
      "<h3>Subject: "+msg['Subject']+"</h3>",
      "<br>",
      "Exmo Sr: <b>"+ nome +'</b>'+ "<br>",
      "Informamos que o documento <i>"+str(doc)+"</i> no valor de "+str(valor)+" ,vence em "+data+" .",
      "Agradecemos o pagamento atraves da conta bancaria ABCD.",
      "<br>",
      "<br>",
      "<br>",
      "Cumprimentos,<br>",
      "Grupo Aco Cearense.<br>" ,
      "<br>",  
      "Sent at:"+strftime("%Y-%m-%d %H:%M:%S", gmtime())  
      ])

    # add in the message body
    #text = MIMEText(message,'plain')
    text = MIMEText(message,'html')
    msg.attach(text)

    # attach image JPG to message body
    if xfile_jpg is not '':
        print('......Tem jpg :', image_file)
        image = MIMEImage(img_data, name=os.path.basename(image_file))
        msg.attach(image)

    # attach PDF to email - OK
    if xfile_pdf is not '': 
        print('......Tem pdf :', file_pdf)
        part = MIMEBase('application', "octet-stream")
        part.set_payload(open(file_pdf, "rb").read())
        encoders.encode_base64(part)
        part.add_header('Content-Disposition', "attachment; filename= %s" % file_pdf)
        msg.attach(part)

    # attach Event Calendar - OK
    if xfile_event is not '': 
        print('......Tem evento :', file_event)
        part = MIMEBase('text', 'calendar',method='REQUEST',name=file_event) #method ='REQUEST' only provide me the possibility of adding 1 event, not 5
        part.set_payload(open(file_event, "rb").read())
        encoders.encode_base64(part)
        part.add_header('Content-Disposition', "attachment; filename= %s" % xfile_event) 
        msg.attach(part)


    # Call function to send email
    print('3.Sent the mail to :', xemail)
    
    send_email(fromaddr, xemail, msg.as_string() )
    return

# %%
def executa_row(nome, doc, data, email, valor, file_pdf, file_jpg, file_event):
    print('1.Exec. Row: ', nome,  email)

    create_msg_email(nome, doc, data, email, valor, file_pdf, file_jpg, file_event)
    return

# teste
# executa_row('manuel SIlva', 'doc123', '13-6-2020', 'manuel.robalinho@hotmail.com', 20000.55, 'file_pdf', 'file_jpg', 'file_event' )

# %%
# Read each line from Dataframe
for index, row in df2.iterrows():
    print('...') 
    print('---> ', index+1)
    executa_row(row['nome'], row['doc'], row['vencimento'], row['email'], row['montante'], row['file_pdf'], row['file_jpg'] , row['file_event'])
    
print('--- Finished ----')
# Out:
# ...
# --->  1
# 1.Exec. Row:  ACO CEARENSE COMERCIAL LTDA manuel.robalinho@acocearense.com.br
# 2.Create msg : ACO CEARENSE COMERCIAL LTDA 90549749 09.04.2016 37060.58
# ......Tem jpg : files_to_attach/teste1.jpg
# ......Tem pdf : files_to_attach/teste1.pdf
# ......Tem evento : files_to_attach/EVENTO_DO_ROBALINHO.ics
# 3.Sent the mail to : manuel.robalinho@acocearense.com.br
# 4.Successfully sent the mail to : manuel.robalinho@acocearense.com.br
# ...
# --->  2
# 1.Exec. Row:  IND COM DE FERROS BORTOLASO LTDA manuel.robalinho@acocearense.com.br
# 2.Create msg : IND COM DE FERROS BORTOLASO LTDA 90554973 15.04.2018 1001.6
# ......Tem jpg : files_to_attach/teste2.jpg
# ......Tem pdf : files_to_attach/teste2.pdf
# ......Tem evento : files_to_attach/EVENTO_DO_ROBALINHO.ics
# 3.Sent the mail to : manuel.robalinho@acocearense.com.br
# 4.Successfully sent the mail to : manuel.robalinho@acocearense.com.br
# ...
# --->  3
# 1.Exec. Row:  CHAPADAOFER IND E COM mrobalinho@hotmail.com
# 2.Create msg : CHAPADAOFER IND E COM 90537461 23.01.2016 3995.84
# ......Tem pdf : files_to_attach/teste2.pdf
# 3.Sent the mail to : mrobalinho@hotmail.com
# 4.Successfully sent the mail to : mrobalinho@hotmail.com
# ...
# --->  4
# 1.Exec. Row:  CHAPADAOFER IND E COM mrobalinho@hotmail.com
# 2.Create msg : CHAPADAOFER IND E COM 90537461 22.02.2016 3995.96
# 3.Sent the mail to : mrobalinho@hotmail.com
# 4.Successfully sent the mail to : mrobalinho@hotmail.com
# --- Finished ----
